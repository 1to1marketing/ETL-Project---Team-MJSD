# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
mlb_file = "Resources/baseballdata.csv"
mlb_df = pd.read_csv(mlb_file)
mlb_df.head()
# Out:
#    Unnamed: 0  Rk  Year                    Tm       Lg    G   W   L  Ties  \
# 0           1   1  2016  Arizona Diamondbacks  NL West  162  69  93     0
# 1           2   2  2015  Arizona Diamondbacks  NL West  162  79  83     0
# 2           3   3  2014  Arizona Diamondbacks  NL West  162  64  98     0
# 3           4   4  2013  Arizona Diamondbacks  NL West  162  81  81     0
# 4           5   5  2012  Arizona Diamondbacks  NL West  162  81  81     0
#
#     W.L.  ...    R   RA Attendance BatAge  PAge  X.Bat X.P  \
# 0  0.426  ...  752  890  2,036,216   26.7  26.4     50  29
# 1  0.488  ...  720  713  2,080,145   26.6  27.1     50  27
# 2  0.395  ...  615  742  2,073,730   27.6  28.0     52  25
# 3  0.500  ...  685  695  2,134,895   28.1  27.6     44  23
# 4  0.500  ...  734  688  2,177,617   28.3  27.4     48  23
#
#             Top.Player                               Managers  \
# 0       J.Segura (5.7)                         C.Hale (69-93)
# 1  P.Goldschmidt (8.8)                         C.Hale (79-83)
# 2  P.Goldschmidt (4.5)  K.Gibson (63-96) and A.Trammell (1-2)
# 3  P.Goldschmidt (7.1)                       K.Gibson (81-81)
# 4         A.Hill (5.0)                       K.Gibson (81-81)
#
#                 current
# 0  Arizona Diamondbacks
# 1  Arizona Diamondbacks
# 2  Arizona Diamondbacks
# 3  Arizona Diamondbacks
# 4  Arizona Diamondbacks
#
# [5 rows x 24 columns]

# %% [markdown]
# # Extract baseball API  DataFrame

# %%
# Create a filtered dataframe from specific columns
mlb_transformed= mlb_df[["Tm", "Year", "Attendance"]].copy()

# Rename the column headers
mlb_transformed = mlb_transformed.rename(columns={"Tm": "team_name",
                                                          "Year": "year",
                                                          "Attendance": "attendance"})

# Clean the data by dropping duplicates and setting the index
#mlb_transformed.drop_duplicates("team_name", inplace=True)
#mlb_transformed.set_index("team_name", inplace=True)

mlb_transformed.head(1000)
# Out:
#                 team_name  year attendance
# 0    Arizona Diamondbacks  2016  2,036,216
# 1    Arizona Diamondbacks  2015  2,080,145
# 2    Arizona Diamondbacks  2014  2,073,730
# 3    Arizona Diamondbacks  2013  2,134,895
# 4    Arizona Diamondbacks  2012  2,177,617
# ..                    ...   ...        ...
# 995        Detroit Tigers  1945  1,280,341
# 996        Detroit Tigers  1944    923,176
# 997        Detroit Tigers  1943    606,287
# 998        Detroit Tigers  1942    580,087
# 999        Detroit Tigers  1941    684,915
#
# [1000 rows x 3 columns]

# %%
connection_string = "postgres:postgres@localhost:5432/baseball_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
mlb_2016_file = "Resources/mlb2016.csv"
mlb_2016_df = pd.read_csv(mlb_2016_file)
mlb_2016_df.head()
# Out:
#                     venue_name       city     name_display_long  year
# 0                  Chase Field    Phoenix  Arizona Diamondbacks  2016
# 1                SunTrust Park    Atlanta        Atlanta Braves  2016
# 2  Oriole Park at Camden Yards  Baltimore     Baltimore Orioles  2016
# 3                  Fenway Park     Boston        Boston Red Sox  2016
# 4                Wrigley Field    Chicago          Chicago Cubs  2016

# %%
mlb_2017_file = "Resources/mlb2017.csv"
mlb_2017_df = pd.read_csv(mlb_2017_file)
mlb_2017_df.head()
# Out:
#                     venue_name       city     name_display_long  year
# 0                  Chase Field    Phoenix  Arizona Diamondbacks  2017
# 1                SunTrust Park    Atlanta        Atlanta Braves  2017
# 2  Oriole Park at Camden Yards  Baltimore     Baltimore Orioles  2017
# 3                  Fenway Park     Boston        Boston Red Sox  2017
# 4                Wrigley Field    Chicago          Chicago Cubs  2017

# %%
frames = [mlb_2017_df, mlb_2016_df] 

mlb_ap_tables = pd.concat(frames)
mlb_ap_tables
# Out:
#                       venue_name           city  \
# 0                    Chase Field        Phoenix
# 1                  SunTrust Park        Atlanta
# 2    Oriole Park at Camden Yards      Baltimore
# 3                    Fenway Park         Boston
# 4                  Wrigley Field        Chicago
# 5          Guaranteed Rate Field        Chicago
# 6       Great American Ball Park     Cincinnati
# 7              Progressive Field      Cleveland
# 8                    Coors Field         Denver
# 9                  Comerica Park        Detroit
# 10              Minute Maid Park        Houston
# 11              Kauffman Stadium    Kansas City
# 12      Angel Stadium of Anaheim        Anaheim
# 13                Dodger Stadium    Los Angeles
# 14                  Marlins Park          Miami
# 15                   Miller Park      Milwaukee
# 16                  Target Field    Minneapolis
# 17                    Citi Field       New York
# 18                Yankee Stadium          Bronx
# 19              Oakland Coliseum        Oakland
# 20            Citizens Bank Park   Philadelphia
# 21                      PNC Park     Pittsburgh
# 22                    Petco Park      San Diego
# 23                     AT&T Park  San Francisco
# 24                  Safeco Field        Seattle
# 25                 Busch Stadium      St. Louis
# 26               Tropicana Field      Tampa Bay
# 27  Globe Life Park in Arlington      Arlington
# 28                 Rogers Centre        Toronto
# 29                Nationals Park     Washington
# 0                    Chase Field        Phoenix
# 1                  SunTrust Park        Atlanta
# 2    Oriole Park at Camden Yards      Baltimore
# 3                    Fenway Park         Boston
# 4                  Wrigley Field        Chicago
# 5          Guaranteed Rate Field        Chicago
# 6       Great American Ball Park     Cincinnati
# 7              Progressive Field      Cleveland
# 8                    Coors Field         Denver
# 9                  Comerica Park        Detroit
# 10              Minute Maid Park        Houston
# 11              Kauffman Stadium    Kansas City
# 12      Angel Stadium of Anaheim        Anaheim
# 13                Dodger Stadium    Los Angeles
# 14                  Marlins Park          Miami
# 15                   Miller Park      Milwaukee
# 16                  Target Field    Minneapolis
# 17                    Citi Field       New York
# 18                Yankee Stadium          Bronx
# 19              Oakland Coliseum        Oakland
# 20            Citizens Bank Park   Philadelphia
# 21                      PNC Park     Pittsburgh
# 22                    Petco Park      San Diego
# 23                     AT&T Park  San Francisco
# 24                  Safeco Field        Seattle
# 25                 Busch Stadium      St. Louis
# 26               Tropicana Field      Tampa Bay
# 27  Globe Life Park in Arlington      Arlington
# 28                 Rogers Centre        Toronto
# 29                Nationals Park     Washington
#
#                 name_display_long  year
# 0            Arizona Diamondbacks  2017
# 1                  Atlanta Braves  2017
# 2               Baltimore Orioles  2017
# 3                  Boston Red Sox  2017
# 4                    Chicago Cubs  2017
# 5               Chicago White Sox  2017
# 6                 Cincinnati Reds  2017
# 7               Cleveland Indians  2017
# 8                Colorado Rockies  2017
# 9                  Detroit Tigers  2017
# 10                 Houston Astros  2017
# 11             Kansas City Royals  2017
# 12  Los Angeles Angels of Anaheim  2017
# 13            Los Angeles Dodgers  2017
# 14                  Miami Marlins  2017
# 15              Milwaukee Brewers  2017
# 16                Minnesota Twins  2017
# 17                  New York Mets  2017
# 18               New York Yankees  2017
# 19              Oakland Athletics  2017
# 20          Philadelphia Phillies  2017
# 21             Pittsburgh Pirates  2017
# 22               San Diego Padres  2017
# 23           San Francisco Giants  2017
# 24               Seattle Mariners  2017
# 25            St. Louis Cardinals  2017
# 26                 Tampa Bay Rays  2017
# 27                  Texas Rangers  2017
# 28              Toronto Blue Jays  2017
# 29           Washington Nationals  2017
# 0            Arizona Diamondbacks  2016
# 1                  Atlanta Braves  2016
# 2               Baltimore Orioles  2016
# 3                  Boston Red Sox  2016
# 4                    Chicago Cubs  2016
# 5               Chicago White Sox  2016
# 6                 Cincinnati Reds  2016
# 7               Cleveland Indians  2016
# 8                Colorado Rockies  2016
# 9                  Detroit Tigers  2016
# 10                 Houston Astros  2016
# 11             Kansas City Royals  2016
# 12  Los Angeles Angels of Anaheim  2016
# 13            Los Angeles Dodgers  2016
# 14                  Miami Marlins  2016
# 15              Milwaukee Brewers  2016
# 16                Minnesota Twins  2016
# 17                  New York Mets  2016
# 18               New York Yankees  2016
# 19              Oakland Athletics  2016
# 20          Philadelphia Phillies  2016
# 21             Pittsburgh Pirates  2016
# 22               San Diego Padres  2016
# 23           San Francisco Giants  2016
# 24               Seattle Mariners  2016
# 25            St. Louis Cardinals  2016
# 26                 Tampa Bay Rays  2016
# 27                  Texas Rangers  2016
# 28              Toronto Blue Jays  2016
# 29           Washington Nationals  2016

# %% [markdown]
# Tansform mlb API

# %%
# Create a filtered dataframe from specific columns
mlb_api_transformed= mlb_ap_tables[["name_display_long", "year", "venue_name", "city"]].copy()

# Rename the column headers
mlb_api_transformed = mlb_transformed.rename(columns={"name_display_long": "team_name",
                                                            "year": "year",
                                                            "city": "city",
                                                            "venue_name": "venue"})

# Clean the data by dropping duplicates and setting the index
#mlb_transformed.drop_duplicates("team_name", inplace=True)
#mlb_transformed.set_index("team_name", inplace=True)

mlb_api_transformed.head(1000)
# Out:
#                 team_name  year attendance
# 0    Arizona Diamondbacks  2016  2,036,216
# 1    Arizona Diamondbacks  2015  2,080,145
# 2    Arizona Diamondbacks  2014  2,073,730
# 3    Arizona Diamondbacks  2013  2,134,895
# 4    Arizona Diamondbacks  2012  2,177,617
# ..                    ...   ...        ...
# 995        Detroit Tigers  1945  1,280,341
# 996        Detroit Tigers  1944    923,176
# 997        Detroit Tigers  1943    606,287
# 998        Detroit Tigers  1942    580,087
# 999        Detroit Tigers  1941    684,915
#
# [1000 rows x 3 columns]
